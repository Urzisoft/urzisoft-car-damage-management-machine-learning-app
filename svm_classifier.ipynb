# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from dependencies import *

# %%
X = []
Y = []

SVM_NEW_RESIZE_VALUE = 450
collect_images_from_files(X, Y, SVM_NEW_RESIZE_VALUE)

# %%
X = np.array(X)
Y = np.array(Y)
X.shape
# Out:
# (248, 450, 450)

# %%
# Sklearn accepts only bidiomensional data, so we have to convert it

X_reshape = X.reshape(len(X), -1)
X_reshape.shape
# Out:
# (248, 202500)

# %%
xTrain, xTest, yTrain, yTest = train_test_split(X_reshape, Y, random_state=10, test_size=.2)

# %%
xTrain.shape, xTest.shape
# Out:
# ((198, 202500), (50, 202500))

# %%
xTrain, xTest = scale_data_tests(xTrain, xTest)

# %%
from sklearn.svm import SVC

# %%
classifier = SVC(C=100)
classifier.fit(xTrain, yTrain)
# Out:
# SVC(C=100)

# %%
classifier.score(xTest, yTest)
# Out:
# 0.48

# %%
test_based_on_images(classifier, 'moderate/', 9, SVM_NEW_RESIZE_VALUE)
